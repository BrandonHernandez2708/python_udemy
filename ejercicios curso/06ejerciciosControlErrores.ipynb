# %% [markdown]
# Crea un script con una division entre cero, maneja el error para evitar que el programa finalice de forma inesperada y envia un mensaje al usuario.

# %%
n1=45
n2=0
try:
  division=n1/n2
except ZeroDivisionError:
  print("No se puede dividir entre cero")
# Out:
# No se puede dividir entre cero

# %% [markdown]
# Crea un script donde incluyas una lista e intentes mostrar un elemento por indice que no exista, controla y muestra el error.

# %%
numeros=[0,3,8,9,6,1]
try:
    print(numeros[3])
except IndexError:
      print("la lista no tiene ese indice")
# Out:
# 9
