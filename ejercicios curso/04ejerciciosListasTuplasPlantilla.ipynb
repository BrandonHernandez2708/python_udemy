# %% [markdown]
# Almacena en una lista diferentes asignaturas y muestralas.

# %%
Materias=["Matemática", "ingles" , "sociales","educacion fisica"]
print("Materias del curso: ", Materias)
# Out:
# Materias del curso:  ['Matemática', 'ingles', 'sociales', 'educacion fisica']

# %% [markdown]
# Almacena nombres en una lista, muestra despues un mensaje saludando a cada persona.

# %%
nombres=["Juan", "Pedro", "Maria", "Ana"]
for persona in nombres:
    print(f"hola {persona}")
# Out:
# hola Juan
# hola Pedro
# hola Maria
# hola Ana

# %% [markdown]
# Guarda en una variable y diccionario con algunos colores usando la clave en español y el valor en ingles.
# Preguntando al usuario por un color y mostrarle su valor en ingles.

# %%
colores={"rojo": "red", "verde": "green", "azul": "blue"}
color_usuario=input("Ingrese un color en español: ")
if color_usuario in colores:
    print(f"El color en inglés es: {colores[color_usuario]}")

# %% [markdown]
# En una tupla coloca numeros decimales, cadenas y listas, despues muestrala.

# %%
tupla=(1,2,3,"hola",["manzanas","peras","naranjas"])
print(tupla)
# Out:
# (1, 2, 3, 'hola', ['manzanas', 'peras', 'naranjas'])
